# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading data

# %%
btc=pd.read_csv('C:\\Users\\Owner\\Desktop\\python\\btc_usd_daily.csv')
eth=pd.read_csv('C:\\Users\\Owner\\Desktop\\python\\eth_usd_daily.csv')
doge=pd.read_csv('C:\\Users\\Owner\\Desktop\\python\\doge_usd_daily.csv')

doge.dtypes
# Out:
# Date         object
# Price       float64
# Open        float64
# High        float64
# Low         float64
# Vol.         object
# Change %     object
# dtype: object

# %% [markdown]
# I wanted to do a histogram of btc prices but since Price is not a float datatype, I had to do this conversion. Replacing commas in strings ad then converting themto float.

# %%
btc_price1=btc['Price'].str.replace(',', '').astype(float)
eth_price1=eth['Price'].str.replace(',', '').astype(float)

plt.hist(btc_price1)
plt.title('BTC Price distribution')
plt.xlabel('Price')
plt.show()

plt.hist(eth_price1)
plt.title('ETH Price distribution')
plt.xlabel('Price')
plt.show()

plt.hist(doge['Price'])
plt.title('DOGE Price distribution')
plt.xlabel('Price')
plt.show()
