# %%
#loading libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing dataset

btc = pd.read_csv("D:/St Clair/Sem 1/DAB 103 Analytics Tool and Decision making/Project/Dataset/btc_usd_daily.csv")
eth = pd.read_csv("D:/St Clair/Sem 1/DAB 103 Analytics Tool and Decision making/Project/Dataset/eth_usd_daily.csv")
doge = pd.read_csv("D:/St Clair/Sem 1/DAB 103 Analytics Tool and Decision making/Project/Dataset/doge_usd_daily.csv")

# %%
btc.describe()
# Out:
#               Price          Open          High           Low     Change %
# count   1453.000000   1453.000000   1453.000000   1453.000000  1453.000000
# mean   12236.468754  12211.429456  12585.464900  11791.916105     0.002746
# std    12930.900744  12914.627096  13347.980278  12403.618064     0.043726
# min     1914.100000   1914.100000   2044.400000   1809.000000    -0.390000
# 25%     6291.300000   6283.700000   6451.700000   6138.800000    -0.020000
# 50%     8304.400000   8302.700000   8536.500000   8110.400000     0.000000
# 75%    10904.500000  10899.400000  11175.200000  10568.800000     0.020000
# max    63540.900000  63544.200000  64778.000000  62067.500000     0.260000

# %%
eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1453 non-null   object
#  1   Price     1453 non-null   float64
#  2   Open      1453 non-null   float64
#  3   High      1453 non-null   float64
#  4   Low       1453 non-null   float64
#  5   Vol.      1453 non-null   object
#  6   Change %  1453 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 79.6+ KB

# %%
doge.tail()
# Out:
#           Date   Price    Open    High     Low   Vol.  Change %
# 1448  7-Jun-17  0.0033  0.0036  0.0040  0.0031  1.37M   -0.1015
# 1449  6-Jun-17  0.0036  0.0037  0.0037  0.0032  2.11M   -0.0272
# 1450  5-Jun-17  0.0037  0.0038  0.0038  0.0029  4.82M   -0.0138
# 1451  4-Jun-17  0.0038  0.0032  0.0038  0.0025  5.96M    0.1734
# 1452  3-Jun-17  0.0032  0.0028  0.0034  0.0027  4.37M    0.1463

# %%
#function to convert Vol to float

def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return 0.0

# %%
#Converting Vol. column to float in all dataset

btc['Vol.'] = btc['Vol.'].apply(value_to_float)
eth['Vol.'] = eth['Vol.'].apply(value_to_float)
doge['Vol.'] = doge['Vol.'].apply(value_to_float)
pd.options.display.float_format = '{:.3f}'.format

# %%
doge.head()
# Out:
#         Date  Price  Open  High   Low           Vol.  Change %
# 0  25-May-21  0.342 0.364 0.380 0.323 8550000000.000    -0.060
# 1  24-May-21  0.364 0.306 0.370 0.296 8160000000.000     0.191
# 2  23-May-21  0.306 0.342 0.350 0.249 9450000000.000    -0.104
# 3  22-May-21  0.342 0.358 0.360 0.318 6330000000.000    -0.047
# 4  21-May-21  0.358 0.398 0.411 0.315 8540000000.000    -0.099

# %%
btc_box = sns.boxplot(data=btc['Price'], orient="h")

# %%
eth_box = sns.boxplot(data=eth['Price'], orient="h")

# %%
btc['Price'].hist(bins=30, figsize=(15,10)).axvline(btc['Price'].median(), color='b', linestyle='dashed', linewidth=2)

# %%
eth['Price'].hist(bins=30, figsize=(15,10)).axvline(eth['Price'].median(), color='b', linestyle='dashed', linewidth=2)

# %%
sns.distplot(btc["Vol."], kde = True)

# %%
# Out:
# a
